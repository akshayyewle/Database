# %%
import jupysql_plugin
import psycopg
from sqlalchemy import create_engine
import os

# %load_ext sql
# %reload_ext sql

password = os.environ['postgres_password']
database = 'postgres'
connection_string = f'postgresql://postgres:{password}@localhost:5432/{database}'

# Create Engine 
engine = create_engine(connection_string)

# Connect to the database
# https://jupysql.ploomber.io/en/latest/connecting.html 
# https://jupysql.ploomber.io/en/latest/connecting.html#building-url-strings-securely
# %sql engine

# %% [markdown]
# # **Query 01**

# %%
# %%sql
#
# CREATE TABLE ticket_moves (
#     ticket_id INT NOT NULL,
#     create_date DATE NOT NULL,
#     move_date DATE NOT NULL,
#     from_stage TEXT NOT NULL,
#     to_stage TEXT NOT NULL);
# Out:
# Running query in 'postgresql://postgres:***@localhost:5432/postgres'
# ++
# ||
# ++
# ++

# %%
# Insert data
# %%sql

INSERT INTO ticket_moves (ticket_id, create_date, move_date, from_stage, to_stage) VALUES
(1, '2024-09-01', '2024-09-03', 'New', 'Doing'),
(1, '2024-09-01', '2024-09-07', 'Doing', 'Review'),
(1, '2024-09-01', '2024-09-10', 'Review', 'Done'),

(2, '2024-09-05', '2024-09-08', 'New', 'Doing'),
(2, '2024-09-05', '2024-09-12', 'Doing', 'Review'),
(2, '2024-09-05', '2024-09-15', 'Review', 'Doing'),
(2, '2024-09-05', '2024-09-20', 'Doing', 'Review'),

(3, '2024-09-10', '2024-09-16', 'New', 'Doing'),

(4, '2024-09-15', '2024-09-22', 'Doing', 'Review')
# Out:
#   Cell In[4], line 4
#     INSERT INTO ticket_moves (ticket_id, create_date, move_date, from_stage, to_stage) VALUES
#            ^
# SyntaxError: invalid syntax

# %%
# Insert data
# %%sql 

INSERT INTO ticket_moves VALUES (1, '2024-09-01', '2024-09-03', 'New', 'Doing');
# Out:
#   Cell In[2], line 4
#     INSERT INTO ticket_moves VALUES (1, '2024-09-01', '2024-09-03', 'New', 'Doing');
#            ^
# SyntaxError: invalid syntax

# %%
# %%sql
#
# SELECT * FROM ticket_moves;
# Out:
# Running query in 'postgresql://postgres:***@localhost:5432/postgres'
# 9 rows affected.
# +-----------+-------------+------------+------------+----------+
# | ticket_id | create_date | move_date  | from_stage | to_stage |
# +-----------+-------------+------------+------------+----------+
# |     1     |  2024-09-01 | 2024-09-03 |    New     |  Doing   |
# |     1     |  2024-09-01 | 2024-09-07 |   Doing    |  Review  |
# |     1     |  2024-09-01 | 2024-09-10 |   Review   |   Done   |
# |     2     |  2024-09-05 | 2024-09-08 |    New     |  Doing   |
# |     2     |  2024-09-05 | 2024-09-12 |   Doing    |  Review  |
# |     2     |  2024-09-05 | 2024-09-15 |   Review   |  Doing   |
# |     2     |  2024-09-05 | 2024-09-20 |   Doing    |  Review  |
# |     3     |  2024-09-10 | 2024-09-16 |    New     |  Doing   |
# |     4     |  2024-09-15 | 2024-09-22 |   Doing    |  Review  |
# +-----------+-------------+------------+------------+----------+

# %%
# %%sql
#
# DROP TABLE ticket_moves;
# Out:
# Running query in 'postgresql://postgres:***@localhost:5432/postgres'
# ++
# ||
# ++
# ++
